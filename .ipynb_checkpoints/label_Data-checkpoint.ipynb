# %%
import os
import pandas as pd
import numpy as np
import requests as req
from bs4 import BeautifulSoup as bs
import time
from difflib import get_close_matches
from fuzzywuzzy import process
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
leaguesDic = {
   "Argentinian-Liga-A": "Liga_Nacional_de_B%C3%A1squet",
    "Basketball-Champions-League-": "Basketball_Champions_League",
    "Adriatic-Junior-Liga-ABA": "Junior_ABA_League",
    "Spanish-LEB-Gold": "LEB_Oro",
    "Italian-Cup": "Italian_Basketball_Cup",
    "French-Leaders-Cup-LNB-B": "LNB_Pro_B_Leaders_Cup",
    "Czech-NBL": "National_Basketball_League_(Czech_Republic)",
    "Austrian-A-Bundesliga": "Austrian_Basketball_Bundesliga",
    "Alpe-Adria-Cup": "Alpe_Adria_Cup",
    "Serbian-KLS": "Basketball_League_of_Serbia",
    "Spanish-Cup": "Copa_del_Rey_de_Baloncesto",
    "BNXT-League": "BNXT_League",
    "FIBA-Europe-Cup---Qualification": "FIBA_Europe_Cup",
    "German-Pro-A": "ProA",
    "Greek-HEBA-A1": "Greek_Basket_League",
    "Cypriot-Division-A": "Cypriot_Basketball_Division_A",
    "Basketball-Africa-League": "Basketball_Africa_League",
    "Georgian-Super-Liga": "Georgian_Superliga",
    "Bulgarian-NBL": "Bulgarian_Basketball_League",
    "NBL-Blitz": "NBL_Blitz",
    "Portuguese-LPB": "Liga_Portuguesa_de_Basquetebol",
    "NBA": "NBA",
    "Swiss-LNA": "Swiss_Basketball_League",
    "British-BBL": "British_Basketball_League",
    "Mexican-CIBACOPA": "CIBACOPA",
    "Lithuanian-NKL": "National_Basketball_League_(Lithuania)",
    "Belgrade-Tournament-(ANGT)": "Adidas_Next_Generation_Tournament",
    "Slovakian-Extraliga": "Slovak_Basketball_League",
    "Romanian-Divizia-A": "Liga_Na%C8%9Bional%C4%83_(men%27s_basketball)",
    "Munich-Tournament-(ANGT)": "Adidas_Next_Generation_Tournament",
    "Lebanese-Division-A": "Lebanese_Basketball_League",
    "VTB-Youth-United-League": "VTB_United_Youth_League",
    "French-Jeep-Elite": "LNB_Pro_A",
    "Norwegian-BLNO": "BLNO",
    "Montenegrin-Prva-A-Liga": "Prva_A_Liga",
    "VTB-United-League": "VTB_United_League",
    "French-NM1": "LNB_Pro_B",
    "New-Zealand-NB": "National_Basketball_League_(New_Zealand)",
    "Luxembourg-Total-League": "Total_League",
    "Turkish-TBL": "Basketball_Super_League",
    "German-BBL": "Basketball_Bundesliga",
    "Chinese-CBA": "Chinese_Basketball_Association",
    "Puerto-Rican-BSN": "Baloncesto_Superior_Nacional",
    "Balkan-BIBL": "BIBL",
    "Bosnian-BiH-Liga": "Basketball_Championship_of_Bosnia_and_Herzegovina",
    "French-Leaders-Cup-LNB-A": "LNB_Pro_A_Leaders_Cup",
    "Swedish-Basketligan": "Basketligan",
    "Basketball-Africa-League---Qualification": "Basketball_Africa_League",
    "FIBA-Europe-Cup": "FIBA_Europe_Cup",
    "Japanese-B.League": "B.League",
    "Turkish-BSL": "Basketball_Super_League",
    "German-Pro-B": "ProB",
    "Euroleague": "EuroLeague",
    "Italian-Serie-A2-Basket": "Serie_A2_(basketball)",
    "Greek-HEBA-A2": "Greek_Basketball_League",
    "Canadian-NBL": "Canadian_Elite_Basketball_League",
    "French-LNB-Pro-B": "LNB_Pro_B",
    "PBA---Philippine-Cup": "PBA_Philippine_Cup",
    "Eurocup": "EuroCup_Basketball",
    "Brazilian-NBB": "Novo_Basquete_Brasil",
    "Belarusian-BPL": "Belarusian_Premier_League_(basketball)",
    "Ukrainian-Superleague": "Ukrainian_Basketball_SuperLeague",
    "Turkish-Cup": "Turkish_Basketball_Cup",
    "Danish-Basketligaen": "Basketligaen",
    "PBA---Governors-Cup": "PBA_Governors'_Cup",
    "Intercontinental-Cup": "FIBA_Intercontinental_Cup",
    "Croatian-A-1-Liga": "Croatian_Basketball_League",
    "Venezuelan-SLB": "Superliga_Profesional_de_Baloncesto",
    "Patras-Tournament-(ANGT)": "Adidas_Next_Generation_Tournament",
    "PBA---Commissioners-Cup": "PBA_Commissioner's_Cup",
    "Estonian-Latvian-Basketball-League": "Baltic_Basketball_League",
    "Slovenian-SKL": "Slovenian_Basketball_League",
    "Serbian-RK-Cup": "Radivoj_Korac_Cup",
    "Lithuanian-LKL": "Lietuvos_krep%C5%A1inio_lyga",
    "Australian-NBL": "National_Basketball_League_(Australia)",
    "Spanish-LEB-Silver": "LEB_Plata",
    "Italian-Lega-Basket-Serie-A": "Lega_Basket_Serie_A",
    "French-LNB-Espoirs": "LNB_Pro_A",
    "Macedonian-Superleague": "Macedonian_First_League_(basketball)",
    "Spanish-ACB-SuperCup": "Supercopa_de_España_de_Baloncesto",
    "Hungarian-NBIA": "NBIA",
    "Israeli-BSL": "Israeli_Basketball_Premier_League",
    "VTB-SuperCup": "VTB_United_League",
    "Finnish-Korisliiga": "Korisliiga",
    "Mexican-LNBP": "Liga_Nacional_de_Baloncesto_Profesional",
    "Kosovo-FBK": "Kosovo_Basketball_Superleague",
    "Spanish-ACB": "Liga_ACB",
    "Canadian-Elite-Basketball-League": "Canadian_Elite_Basketball_League",
    "German-Cup": "BBL-Pokal",
    "Polish-EB": "Polish_Basketball_League",
    "South-Korean-KBL": "Korean_Basketball_League",
    "Adriatic-League-Liga-ABA": "ABA_League",
    "Youth-Basketball-Champions-League": "Basketball_Champions_League",
    "Zadar-Tournament-(ANGT)": "Adidas_Next_Generation_Tournament"
}
dynamicURL  = "https://en.wikipedia.org/wiki/"
dfList =[]

# %%
#Checking that all URLs are valid
for league in leaguesDic.values():
        res = req.get(dynamicURL+league)
        if(res.status_code == 404):
            print(f"{res} in {league}")
print("finish")
# Out:
# <Response [404]> in NBL_Blitz
# finish

# %%
##Inserting All Tables from Wiki to a dictionry with League Name as a key
tablesDic = {}
count =0
for league in leaguesDic:
    currURL = dynamicURL + leaguesDic[league]
    try:
        tablesDic[league] = pd.read_html(currURL)
        print(f"for {league} tables has been added!")
    except:
        tablesDic[league] = None
        count+=1
        print(f"for {league} inseration has failed!")
        continue
print(f"total Failed:{count}")
# Out:
# for Argentinian-Liga-A tables has been added!
# for Basketball-Champions-League- tables has been added!
# for  Adriatic-Junior-Liga-ABA tables has been added!
# for Spanish-LEB-Gold tables has been added!
# for Italian-Cup tables has been added!
# for French-Leaders-Cup-LNB-B tables has been added!
# for Czech-NBL tables has been added!
# for Austrian-A-Bundesliga tables has been added!
# for Alpe-Adria-Cup tables has been added!
# for  Serbian-KLS tables has been added!
# for Spanish-Cup tables has been added!
# for BNXT-League tables has been added!
# for FIBA-Europe-Cup---Qualification tables has been added!
# for German-Pro-A inseration has failed!
# for  Greek-HEBA-A1 tables has been added!
# for Cypriot-Division-A tables has been added!
# for Basketball-Africa-League tables has been added!
# for Georgian-Super-Liga tables has been added!
# for Bulgarian-NBL tables has been added!
# for NBL-Blitz inseration has failed!
# for Portuguese-LPB tables has been added!
# for NBA tables has been added!
# for Swiss-LNA tables has been added!
# for British-BBL tables has been added!
# for Mexican-CIBACOPA tables has been added!
# for Lithuanian-NKL tables has been added!
# for  Belgrade-Tournament-(ANGT) tables has been added!
# for Slovakian-Extraliga tables has been added!
# for  Romanian-Divizia-A tables has been added!
# for Munich-Tournament-(ANGT) tables has been added!
# for Lebanese-Division-A tables has been added!
# for VTB-Youth-United-League tables has been added!
# for French-Jeep-Elite tables has been added!
# for Norwegian-BLNO tables has been added!
# for  Montenegrin-Prva-A-Liga tables has been added!
# for VTB-United-League tables has been added!
# for French-NM1 tables has been added!
# for  New-Zealand-NB tables has been added!
# for Luxembourg-Total-League tables has been added!
# for Turkish-TBL tables has been added!
# for German-BBL tables has been added!
# for Chinese-CBA tables has been added!
# for Puerto-Rican-BSN tables has been added!
# for  Balkan-BIBL tables has been added!
# for  Bosnian-BiH-Liga tables has been added!
# for French-Leaders-Cup-LNB-A tables has been added!
# for Swedish-Basketligan tables has been added!
# for Basketball-Africa-League---Qualification tables has been added!
# for FIBA-Europe-Cup tables has been added!
# for Japanese-B.League tables has been added!
# for Turkish-BSL tables has been added!
# for German-Pro-B tables has been added!
# for Euroleague tables has been added!
# for Italian-Serie-A2-Basket tables has been added!
# for Greek-HEBA-A2 tables has been added!
# for Canadian-NBL tables has been added!
# for  French-LNB-Pro-B tables has been added!
# for PBA---Philippine-Cup tables has been added!
# for Eurocup tables has been added!
# for Brazilian-NBB tables has been added!
# for Belarusian-BPL tables has been added!
# for Ukrainian-Superleague tables has been added!
# for Turkish-Cup tables has been added!
# for Danish-Basketligaen tables has been added!
# for PBA---Governors-Cup tables has been added!
# for Intercontinental-Cup tables has been added!
# for Croatian-A-1-Liga tables has been added!
# for Venezuelan-SLB inseration has failed!
# for Patras-Tournament-(ANGT) tables has been added!
# for PBA---Commissioners-Cup tables has been added!
# for Estonian-Latvian-Basketball-League tables has been added!
# for Slovenian-SKL tables has been added!
# for  Serbian-RK-Cup tables has been added!
# for Lithuanian-LKL tables has been added!
# for  Australian-NBL tables has been added!
# for Spanish-LEB-Silver tables has been added!
# for Italian-Lega-Basket-Serie-A tables has been added!
# for French-LNB-Espoirs tables has been added!
# for  Macedonian-Superleague tables has been added!
# for Spanish-ACB-SuperCup tables has been added!
# for Hungarian-NBIA tables has been added!
# for  Israeli-BSL tables has been added!
# for VTB-SuperCup tables has been added!
# for Finnish-Korisliiga tables has been added!
# for Mexican-LNBP tables has been added!
# for Kosovo-FBK tables has been added!
# for Spanish-ACB tables has been added!
# for Canadian-Elite-Basketball-League tables has been added!
# for German-Cup tables has been added!
# for Polish-EB tables has been added!
# for South-Korean-KBL tables has been added!
# for Adriatic-League-Liga-ABA tables has been added!
# for Youth-Basketball-Champions-League tables has been added!
# for Zadar-Tournament-(ANGT) tables has been added!
# total Failed:3

# %%
##Taking out all the Champions Tables to new dictonary From allTables dic
## Need To take Out Venzuelian,ProA,BLitz
championsTableDic={}
counter=0
for leagueName in tablesDic:
    print(leagueName)
    if(tablesDic[leagueName] != None):
        for table in tablesDic[leagueName]:
            if(type(table.columns) == pd.MultiIndex): ## Checking if the word is in MultiIndex
                if("Champion" in table.columns.get_level_values(1) or "Champions" in table.columns.get_level_values(1) or "Champions" in table.columns.get_level_values(0) or "Champion" in table.columns.get_level_values(0) or "Gold" in table.columns.get_level_values(1)):
                    counter +=1
                    championsTableDic[leagueName] = table
                    print(f"The Champions table has been found for:{leagueName}")
                    break
                
                
            elif("Champion" in table.columns or "Winners" in table.columns or "Champions" in table.columns or "Years won" in table.columns or "Year(s) won" in table.columns or "Winner" in table.columns or "Champion years" in table.columns):
                counter +=1
                championsTableDic[leagueName] = table
                print(f"The Champions table has been found for:{leagueName}")
                break
            
        
                
print(len(tablesDic))
print(counter)
# Out:
# Argentinian-Liga-A
# The Champions table has been found for:Argentinian-Liga-A
# Basketball-Champions-League-
# The Champions table has been found for:Basketball-Champions-League-
#  Adriatic-Junior-Liga-ABA
# The Champions table has been found for: Adriatic-Junior-Liga-ABA
# Spanish-LEB-Gold
# The Champions table has been found for:Spanish-LEB-Gold
# Italian-Cup
# The Champions table has been found for:Italian-Cup
# French-Leaders-Cup-LNB-B
# The Champions table has been found for:French-Leaders-Cup-LNB-B
# Czech-NBL
# The Champions table has been found for:Czech-NBL
# Austrian-A-Bundesliga
# The Champions table has been found for:Austrian-A-Bundesliga
# Alpe-Adria-Cup
# The Champions table has been found for:Alpe-Adria-Cup
#  Serbian-KLS
# The Champions table has been found for: Serbian-KLS
# Spanish-Cup
# The Champions table has been found for:Spanish-Cup
# BNXT-League
# The Champions table has been found for:BNXT-League
# FIBA-Europe-Cup---Qualification
# The Champions table has been found for:FIBA-Europe-Cup---Qualification
# German-Pro-A
#  Greek-HEBA-A1
# The Champions table has been found for: Greek-HEBA-A1
# Cypriot-Division-A
# The Champions table has been found for:Cypriot-Division-A
# Basketball-Africa-League
# The Champions table has been found for:Basketball-Africa-League
# Georgian-Super-Liga
# The Champions table has been found for:Georgian-Super-Liga
# Bulgarian-NBL
# The Champions table has been found for:Bulgarian-NBL
# NBL-Blitz
# Portuguese-LPB
# The Champions table has been found for:Portuguese-LPB
# NBA
# The Champions table has been found for:NBA
# Swiss-LNA
# The Champions table has been found for:Swiss-LNA
# British-BBL
# The Champions table has been found for:British-BBL
# Mexican-CIBACOPA
# The Champions table has been found for:Mexican-CIBACOPA
# Lithuanian-NKL
# The Champions table has been found for:Lithuanian-NKL
#  Belgrade-Tournament-(ANGT)
# The Champions table has been found for: Belgrade-Tournament-(ANGT)
# Slovakian-Extraliga
# The Champions table has been found for:Slovakian-Extraliga
#  Romanian-Divizia-A
# The Champions table has been found for: Romanian-Divizia-A
# Munich-Tournament-(ANGT)
# The Champions table has been found for:Munich-Tournament-(ANGT)
# Lebanese-Division-A
# The Champions table has been found for:Lebanese-Division-A
# VTB-Youth-United-League
# The Champions table has been found for:VTB-Youth-United-League
# French-Jeep-Elite
# The Champions table has been found for:French-Jeep-Elite
# Norwegian-BLNO
# The Champions table has been found for:Norwegian-BLNO
#  Montenegrin-Prva-A-Liga
# The Champions table has been found for: Montenegrin-Prva-A-Liga
# VTB-United-League
# The Champions table has been found for:VTB-United-League
# French-NM1
# The Champions table has been found for:French-NM1
#  New-Zealand-NB
# The Champions table has been found for: New-Zealand-NB
# Luxembourg-Total-League
# The Champions table has been found for:Luxembourg-Total-League
# Turkish-TBL
# The Champions table has been found for:Turkish-TBL
# German-BBL
# The Champions table has been found for:German-BBL
# Chinese-CBA
# The Champions table has been found for:Chinese-CBA
# Puerto-Rican-BSN
# The Champions table has been found for:Puerto-Rican-BSN
#  Balkan-BIBL
# The Champions table has been found for: Balkan-BIBL
#  Bosnian-BiH-Liga
# The Champions table has been found for: Bosnian-BiH-Liga
# French-Leaders-Cup-LNB-A
# The Champions table has been found for:French-Leaders-Cup-LNB-A
# Swedish-Basketligan
# The Champions table has been found for:Swedish-Basketligan
# Basketball-Africa-League---Qualification
# The Champions table has been found for:Basketball-Africa-League---Qualification
# FIBA-Europe-Cup
# The Champions table has been found for:FIBA-Europe-Cup
# Japanese-B.League
# The Champions table has been found for:Japanese-B.League
# Turkish-BSL
# The Champions table has been found for:Turkish-BSL
# German-Pro-B
# The Champions table has been found for:German-Pro-B
# Euroleague
# The Champions table has been found for:Euroleague
# Italian-Serie-A2-Basket
# The Champions table has been found for:Italian-Serie-A2-Basket
# Greek-HEBA-A2
# The Champions table has been found for:Greek-HEBA-A2
# Canadian-NBL
# The Champions table has been found for:Canadian-NBL
#  French-LNB-Pro-B
# The Champions table has been found for: French-LNB-Pro-B
# PBA---Philippine-Cup
# The Champions table has been found for:PBA---Philippine-Cup
# Eurocup
# The Champions table has been found for:Eurocup
# Brazilian-NBB
# The Champions table has been found for:Brazilian-NBB
# Belarusian-BPL
# The Champions table has been found for:Belarusian-BPL
# Ukrainian-Superleague
# The Champions table has been found for:Ukrainian-Superleague
# Turkish-Cup
# The Champions table has been found for:Turkish-Cup
# Danish-Basketligaen
# The Champions table has been found for:Danish-Basketligaen
# PBA---Governors-Cup
# The Champions table has been found for:PBA---Governors-Cup
# Intercontinental-Cup
# The Champions table has been found for:Intercontinental-Cup
# Croatian-A-1-Liga
# The Champions table has been found for:Croatian-A-1-Liga
# Venezuelan-SLB
# Patras-Tournament-(ANGT)
# The Champions table has been found for:Patras-Tournament-(ANGT)
# PBA---Commissioners-Cup
# The Champions table has been found for:PBA---Commissioners-Cup
# Estonian-Latvian-Basketball-League
# The Champions table has been found for:Estonian-Latvian-Basketball-League
# Slovenian-SKL
# The Champions table has been found for:Slovenian-SKL
#  Serbian-RK-Cup
# The Champions table has been found for: Serbian-RK-Cup
# Lithuanian-LKL
# The Champions table has been found for:Lithuanian-LKL
#  Australian-NBL
# The Champions table has been found for: Australian-NBL
# Spanish-LEB-Silver
# The Champions table has been found for:Spanish-LEB-Silver
# Italian-Lega-Basket-Serie-A
# The Champions table has been found for:Italian-Lega-Basket-Serie-A
# French-LNB-Espoirs
# The Champions table has been found for:French-LNB-Espoirs
#  Macedonian-Superleague
# The Champions table has been found for: Macedonian-Superleague
# Spanish-ACB-SuperCup
# The Champions table has been found for:Spanish-ACB-SuperCup
# Hungarian-NBIA
# The Champions table has been found for:Hungarian-NBIA
#  Israeli-BSL
# The Champions table has been found for: Israeli-BSL
# VTB-SuperCup
# The Champions table has been found for:VTB-SuperCup
# Finnish-Korisliiga
# The Champions table has been found for:Finnish-Korisliiga
# Mexican-LNBP
# The Champions table has been found for:Mexican-LNBP
# Kosovo-FBK
# The Champions table has been found for:Kosovo-FBK
# Spanish-ACB
# The Champions table has been found for:Spanish-ACB
# Canadian-Elite-Basketball-League
# The Champions table has been found for:Canadian-Elite-Basketball-League
# German-Cup
# The Champions table has been found for:German-Cup
# Polish-EB
# The Champions table has been found for:Polish-EB
# South-Korean-KBL
# The Champions table has been found for:South-Korean-KBL
# Adriatic-League-Liga-ABA
# The Champions table has been found for:Adriatic-League-Liga-ABA
# Youth-Basketball-Champions-League
# The Champions table has been found for:Youth-Basketball-Champions-League
# Zadar-Tournament-(ANGT)
# The Champions table has been found for:Zadar-Tournament-(ANGT)
# 94
# 91

# %%
##Saving all Tables to CSV
folderPath = os.getcwd()+ os.sep +"Champions_Tables"
print(folderPath)
for leauge in championsTableDic:
    print(type(championsTableDic[leauge]))
    df = championsTableDic[leauge]
    ##Before Saving Make all the Tables in Same Format of Needed Cols
    
    df.to_csv(folderPath+"/"+leauge+".csv",index=False)
# Out:
# /Users/araddavid/Desktop/Project Python/Predict-Playoff-Teams/Champions_Tables
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
##Start Running From Here####
dfListSeason=[]
dfListClub=[]
folderPath = os.getcwd()+ os.sep +"Champions_Tables"

championsTables =  os.listdir(folderPath)
championsTables.remove(".DS_Store")
###Taking out all the tables and ordring it into 2 diffrent lists
for table in championsTables:
    leagueName = table[0:-4]
    df = pd.read_csv(folderPath+"/"+table)
    if("Season" in df.columns or "Year" in df.columns):
        df = df.rename(columns={"Year":"Season"}) ## Making all Dfs Simmilar
        dfListSeason.append((leagueName,df))
    else:
        df = df.rename(columns={"Club":"Team","Teams":"Team","Champion":"Team","Champions":"Team"})
        dfListClub.append((leagueName,df))

# %%
countAtte=0
champTuppleYears={}
##Moving on the tables that are by Season as row and adding the final label
for curr in dfListSeason:
    lName = curr[0]
    spefTable = curr[1]
    spefFolderPath = os.getcwd()+ os.sep +lName
    
    for col in ["Champions","Champion","Winner","Winners","Final","Finals"]:
        try:
            champTuppleYears[lName]= (list(zip(spefTable["Season"],spefTable[col])))
            countAtte=0
            break
            
        except:
            countAtte+=1
            if(countAtte == 6):
                print(f"Dosent Work for this Leauge:{lName}")
            continue

# %%
champTuppleClub={}
##Moving on the tables that are by Team as row and adding the final label
for curr in dfListClub:
    name=curr[0]
    clubTable = curr[1]
    spefFolderPath = os.getcwd()+ os.sep +name

    for col in ["Winning Years","Year(s) won","Years won","Years","league title","Winning years"]:
        try:
            champTuppleClub[name]= (list(zip(clubTable["Team"],clubTable[col])))
        except:
            continue

# %%
####Here need to build the function to fit the lables to the tables
##Handle The Years
totCounter=0
succCounter=0
for leauge in champTuppleYears:
    for season in champTuppleYears[leauge]:
        totCounter+=1
        ###Taking Out the Year and champ
        currSeason = season[0]
        currChamp = season[1]
           
        try:
            ##The Years in the tables format is : 2022-23 for 2023 season ,so taking the right side and doing as normal year Presnation
            if(int(season[0][-2:len(season[0])]) <= 23):
                currSeason = 2000 + int(season[0][-2:len(season[0])])
            else:
                currSeason = 1900 + int(season[0][-2:len(season[0])])
                
            ###Loading The Correct Table  
            if(leauge == "Zadar-Tournament-(ANGT)" or leauge == "Youth-Basketball-Champions-League"): ##Those 2 are not in Folders 
                currTableLink = os.getcwd()+ os.sep + leauge + "_" + str(currSeason)+".csv"
            else:
                 currTableLink = os.getcwd()+ os.sep + leauge + os.sep + leauge + "_" + str(currSeason)+".csv"
                
            currTable = pd.read_csv(currTableLink)
            ##Last CheckPoint
            print(f"In:{leauge} Season:{currSeason} the champion is:{currChamp}")
            
            ##Here We need to add function thats finds team in Team Colunm that close enougth to currChamp 
            #champInTable = get_close_matches(currChamp,currTable["Team"])[0]
            champInTable = process.extractOne(currChamp, currTable["Team"])
            print(champInTable[0])
            if(len(champInTable) >=1):
                succCounter+=1

        
            mask = currTable["Team"].str.contains(champInTable[0])
            currTable["is_Champion"] = np.where(mask,1,0)
            
            ###Saving the Tables with the labels
            currTable.to_csv(currTableLink,index=False)
               
        except:
               continue
                
print(f"Succses for:{succCounter} from:{totCounter}")
# Out:
# In:Romanian-Divizia-A Season:2012 the champion is:Asesoft Ploiești
# CSU Asesoft Ploiesti
# In:Romanian-Divizia-A Season:2013 the champion is:Asesoft Ploiești
# CSU Asesoft Ploiesti
# In:Romanian-Divizia-A Season:2014 the champion is:Asesoft Ploiești
# CSU Asesoft Ploiesti
# In:Romanian-Divizia-A Season:2015 the champion is:Asesoft Ploiești
# CSU Asesoft Ploiesti
# In:Romanian-Divizia-A Season:2016 the champion is:CSM Oradea
# CSM Oradea
# In:Romanian-Divizia-A Season:2017 the champion is:U-BT Cluj-Napoca
# U-Banca Transilvania Cluj
# In:Belgrade-Tournament-(ANGT) Season:2021 the champion is:Real Madrid
# Maccabi Tel Aviv U18
# In:Belgrade-Tournament-(ANGT) Season:2022 the champion is:Mega Mozzart
# KK Mega Leks U18
# In:Belgrade-Tournament-(ANGT) Season:2023 the champion is:Real Madrid
# KK Crvena Zvezda Youth
# In:BNXT-League Season:2022 the champion is:ZZ Leiden
# ZZ Leiden
# Succses for:394 from:1476

# %%
dontNeedYearsManip = ["NBA","Youth-Basketball-Champions-League","Bulgarian-NBL","Macedonian-Superleague","Turkish-BSL","Basketball-Champions-League-","Bosnian-BiH-Liga"
                     ,"Czech-NBL","Basketball-Africa-League","New-Zealand-NB","Spanish-Cup","Australian-NBL","Turkish-TBL","French-Leaders-Cup-LNB-A",
                     "FIBA-Europe-Cup---Qualification","Puerto-Rican-BSN","Basketball-Africa-League---Qualification","FIBA-Europe-Cup","Mexican-CIBACOPA"]

for league in champTuppleClub:

    print(league)
    ##Passing all the Teams and their years :  
    for teamDet in champTuppleClub[league]:
        team = teamDet[0]
        years = str(teamDet[1]).split(",") ## need to split the years by , beacuse its format
     
            
        for i in years: ## Passing trough all teams champioship Years
            if(league not in dontNeedYearsManip): ## some Tables their format is :1944-45 so need to take out the 45 and make it as 1945 ...
                try:
                    currYear = i.split("–")[1]
                    ## all Year that <= 23 it's 2000+ and >23 its 1900
                    if(int(currYear) <=23):
                        currYear = str(2000 + int(currYear))
                    else:
                        currYear = str(1900 + int(currYear))
                except:
                    currYear = i
            else:
                currYear = i
            ##Some years was saved with spacebar at the start so need to take it off  
            if(currYear[0] == " "):
                 currYear = currYear[1:len(currYear)]
            ## Teams who didnt won any championship has those signs       
            if(currYear !="–" and currYear !="—" and currYear !="/"):
                try:
                    if(league == "Youth-Basketball-Champions-League"): ##This leauge is not in Folder
                        currTablePath = os.getcwd()+ os.sep + league + "_" + currYear +".csv"
                    else:
                        if(league == "NBA"): ## all other leauges saved with _
                            currTablePath = os.getcwd()+ os.sep + league + os.sep + league +"-" + currYear +".csv"
                        else:
                            currTablePath = os.getcwd()+ os.sep + league + os.sep + league +"_" + currYear +".csv"
                    
                    currTable = pd.read_csv(currTablePath)
                    champInTable = process.extractOne(team, currTable["Team"]) ## Beacuse Labels was taken from other source not all the name equal to the tables
                    mask = currTable["Team"].str.contains(champInTable[0]) ## making an true/false list 
                    currTable["is_Champion"] = np.where(mask,1,0)
            
                    ###Saving the Tables with the labels
                    currTable.to_csv(currTablePath,index=False)
                    print("Saved")
                except:
                    continue
# Out:
# Eurocup
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# NBA
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Youth-Basketball-Champions-League
# Saved
# Montenegrin-Prva-A-Liga
# Australian-NBL
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Italian-Lega-Basket-Serie-A
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Bosnian-BiH-Liga
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Czech-NBL
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Basketball-Africa-League
# Saved
# Saved
# Serbian-KLS
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Bulgarian-NBL
# Saved
# Saved
# Saved
# Croatian-A-1-Liga
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Macedonian-Superleague
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Euroleague
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Turkish-BSL
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# New-Zealand-NB
# Spanish-Cup
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# French-LNB-Espoirs
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# German-BBL
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Basketball-Champions-League-
# French-Jeep-Elite
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Swiss-LNA
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Greek-HEBA-A2
# Saved
# Saved
# Saved
# Saved
# Turkish-TBL
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Basketball-Africa-League---Qualification
# Saved
# Greek-HEBA-A1
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Puerto-Rican-BSN
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# FIBA-Europe-Cup---Qualification
# Saved
# Saved
# Saved
# Saved
# Mexican-CIBACOPA
# Saved
# Saved
# Saved
# French-Leaders-Cup-LNB-A
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Hungarian-NBIA
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# FIBA-Europe-Cup
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved
# Saved

# %%
champTuppleClub
# Out:
# {'Eurocup': [('Valencia Basket', '2002–03, 2009–10, 2013–14, 2018–19'),
#   ('Rytas', '2004–05, 2008–09'),
#   ('Khimki', '2011–12, 2014–15'),
#   ('UNICS', '2010–11'),
#   ('Real Madrid', '2006–07'),
#   ('Lokomotiv Kuban', '2012–13'),
#   ('Gran Canaria', '2022–23'),
#   ('Hapoel Jerusalem', '2003–04'),
#   ('Dynamo Moscow', '2005–06'),
#   ('Joventut', '2007–08'),
#   ('Galatasaray', '2015–16'),
#   ('Málaga', '2016–17'),
#   ('Darüşşafaka', '2017–18'),
#   ('Monaco', '2020–21'),
#   ('Virtus Bologna', '2021–22'),
#   ('Alba Berlin', '–'),
#   ('Krka', '–'),
#   ('Makedonikos', '–'),
#   ('Aris', '–'),
#   ('Girona', '–'),
#   ('Real Betis', '–'),
#   ('Bilbao', '–'),
#   ('Strasbourg', '–'),
#   ('Bursapor', '–'),
#   ('Türk Telekom', '–')],
#  'NBA': [('Minneapolis/Los Angeles Lakers',
#    '1949, 1950, 1952, 1953, 1954, 1972, 1980, 1982, 1985, 1987, 1988, 2000, 2001, 2002, 2009, 2010, 2020'),
#   ('Boston Celtics',
#    '1957, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1968, 1969, 1974, 1976, 1981, 1984, 1986, 2008'),
#   ('Philadelphia/San Francisco/Golden State Warriors',
#    '1947, 1956, 1975, 2015, 2017, 2018, 2022'),
#   ('Chicago Bulls', '1991, 1992, 1993, 1996, 1997, 1998'),
#   ('San Antonio Spurs', '1999, 2003, 2005, 2007, 2014'),
#   ('Syracuse Nationals/Philadelphia 76ers', '1955, 1967, 1983'),
#   ('Fort Wayne/Detroit Pistons', '1989, 1990, 2004'),
#   ('Miami Heat', '2006, 2012, 2013'),
#   ('New York Knicks', '1970, 1973'),
#   ('Houston Rockets', '1994, 1995'),
#   ('Milwaukee Bucks', '1971, 2021'),
#   ('Cleveland Cavaliers', '2016'),
#   ('St. Louis/Atlanta Hawks', '1958'),
#   ('Baltimore/Washington Bullets (now Washington Wizards)', '1978'),
#   ('Seattle SuperSonics/Oklahoma City Thunder', '1979'),
#   ('Portland Trail Blazers', '1977'),
#   ('Dallas Mavericks', '2011'),
#   ('Baltimore Bullets (original) (folded in 1954)', '1948'),
#   ('Rochester Royals (now Sacramento Kings)', '1951'),
#   ('Toronto Raptors', '2019'),
#   ('Phoenix Suns', '—'),
#   ('Utah Jazz (formerly New Orleans Jazz)', '—'),
#   ('New Jersey Nets (now Brooklyn Nets)', '—'),
#   ('Orlando Magic', '—'),
#   ('Chicago Stags (folded in 1950)', '—'),
#   ('Washington Capitols (folded in 1951)', '—'),
#   ('Indiana Pacers', '—')],
#  'Youth-Basketball-Champions-League': [('Canarias', '2017, 2022'),
#   ('San Pablo Burgos', '2020, 2021'),
#   ('AEK', '2018'),
#   ('Virtus Bologna', '2019'),
#   ('Baskets Bonn', '2023'),
#   ('Bandırma', '–'),
#   ('Monaco', '–'),
#   ('Karşıyaka', '–'),
#   ('Manresa', '–'),
#   ('Hapoel Jerusalem', '–')],
#  'Montenegrin-Prva-A-Liga': [('KK Budućnost Podgorica',
#    '1998–99, 1999–00, 2000–01')],
#  'Australian-NBL': [('Perth Wildcats',
#    '1990, 1991, 1995, 2000, 2010, 2014, 2016, 2017, 2019, 2020'),
#   ('Melbourne United', '1993, 1997, 2006, 2008, 2018, 2021'),
#   ('Sydney Kings', '2003, 2004, 2005, 2022, 2023'),
#   ('Adelaide 36ers', '1986, 1998, 1999, 2002'),
#   ('New Zealand Breakers', '2011, 2012, 2013, 2015'),
#   ('Canberra Cannons†', '1983, 1984, 1988'),
#   ('Brisbane Bullets', '1985, 1987, 2007'),
#   ('St. Kilda Saints†', '1979, 1980'),
#   ('North Melbourne Giants†', '1989, 1994'),
#   ('S.E. Melbourne Magic†', '1992, 1996'),
#   ('Launceston Casino City†', '1981'),
#   ('West Adelaide Bearcats*', '1982'),
#   ('Illawarra Hawks', '2001'),
#   ('South Dragons†', '2009')],
#  'Italian-Lega-Basket-Serie-A': [('Olimpia Milano',
#    '1935–36, 1936–37, 1937–38, 1938–39, 1949–50, 1950–51, 1951–52, 1952–53, 1953–54, 1956–57, 1957–58, 1958–59, 1959–60, 1961–62, 1962–63, 1964–65, 1965–66, 1966–67, 1971–72, 1981–82, 1984–85, 1985–86, 1986–87, 1988–89, 1995–96, 2013–14, 2015–16, 2017–18, 2021–22'),
#   ('Virtus Bologna',
#    '1945–46, 1946–47, 1947–48, 1948–49, 1954–55, 1955–56, 1975–76, 1978–79, 1979–80, 1983–84, 1992–93, 1993–94, 1994–95, 1997–98, 2000–01, 2020–21'),
#   ('Varese',
#    '1960–61, 1963–64, 1968–69, 1969–70, 1970–71, 1972–73, 1973–74, 1976–77, 1977–78, 1998–99'),
#   ('Mens Sana 1871', '2003–04, 2006–07, 2007–08, 2008–09, 2009–10, 2010–11'),
#   ('Assi Milano', '1921, 1922, 1924, 1925, 1926, 1927'),
#   ('Trieste(formerly Ginnastica Triestina)',
#    '1930, 1932, 1934, 1939–40, 1940–41'),
#   ('Treviso', '1991–92, 1996–97, 2001–02, 2002–03, 2005–06'),
#   ('Ginnastica Roma', '1928, 1931, 1933, 1935'),
#   ('Reyer Venezia', '1941–42, 1942–43, 2016–17, 2018–19'),
#   ('Cantù', '1967–68, 1974–75, 1980–81'),
#   ('Victoria Libertas', '1987–88, 1989–90'),
#   ('Fortitudo Bologna', '1999–00, 2004–05'),
#   ('SEF Costanza Milano', '1920'),
#   ('Internazionale Milano', '1923'),
#   ('Virtus Roma', '1982–83'),
#   ('JuveCaserta', '1990–91'),
#   ('Dinamo Sassari', '2014–15')],
#  'Bosnian-BiH-Liga': [('Široki',
#    '2002, 2003, 2004, 2007, 2009, 2010, 2011, 2012, 2019, 2021'),
#   ('Igokea', '2001, 2013, 2014, 2015, 2016, 2017, 2020, 2022'),
#   ('Bosna Royal', '2005, 2006, 2008'),
#   ('Borac Banja Luka', '2000'),
#   ('Zrinjski', '2018')],
#  'Czech-NBL': [('Nymburk',
#    '2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022'),
#   ('Opava', '1997, 1998, 2002, 2003'),
#   ('USK Praha', '1993, 2000, 2001'),
#   ('Brno', '1994, 1995, 1996'),
#   ('Nový Jičín', '1999')],
#  'Basketball-Africa-League': [('US Monastir', '2022'),
#   ('Zamalek', '2021'),
#   ('Petro de Luanda', '—')],
#  'Serbian-KLS': [('Partizan',
#    '2006–07, 2007–08, 2008–09, 2009–10, 2010–11, 2011–12, 2012–13, 2013–14'),
#   ('Crvena zvezda',
#    '2014–15, 2015–16, 2016–17, 2017–18, 2018–19, 2020–21, 2021–22'),
#   ('Vršac', nan),
#   ('FMP', nan),
#   ('Mega Soccerbet', nan)],
#  'Bulgarian-NBL': [('Academic Sofia',
#    '1957, 1958, 1959, 1963, 1968, 1969, 1970, 1971, 1972, 1973, 1975, 1976, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014–15, 2015–16, 2016–17'),
#   ('Levski Sofia',
#    '1942, 1945, 1946, 1947, 1978, 1979, 1981, 1982, 1986, 1993, 1994, 2000, 2001, 2014, 2017–18, 2020-21'),
#   ('CSKA Sofia',
#    '1949, 1950, 1951, 1965, 1967, 1977, 1980, 1983, 1984, 1990, 1991, 1992'),
#   ('Lokomotiv Sofia', '1943, 1948, 1955, 1961, 1964, 1966'),
#   ('Balkan Botevgrad', '1974, 1987, 1988, 1989, 2018–19, 2021–22'),
#   ('Spartak Sofia', '1954, 1956, 1960, 1962'),
#   ('Slavia Sofia', '1952, 1953, 1997'),
#   ('Cherno More Port Varna', '1985, 1998, 1999'),
#   ('Spartak Pleven', '1995, 1996'),
#   ('Yambol', '2002')],
#  'Croatian-A-1-Liga': [('Cibona',
#    '1991–92, 1992–93, 1993–94, 1994–95, 1995–96, 1996–97, 1997–98, 1998–99, 1999–00, 2000–01, 2001–02, 2003–04, 2005–06, 2006–07, 2008–09, 2009–10, 2011–12, 2012–13, 2018–19, 2021–22'),
#   ('Cedevita', '2013–14, 2014–15, 2015–16, 2016–17, 2017–18'),
#   ('Zadar', '2004–05, 2007–08, 2020–21'),
#   ('Split', '2002–03'),
#   ('Zagreb', '2010–11')],
#  'Macedonian-Superleague': [('Rabotnički',
#    '1993, 1994, 1995, 1996, 1997, 1998, 1999, 2001, 2002, 2003, 2004, 2005, 2006, 2009, 2018'),
#   ('MZT Skopje Aerodrom',
#    '2012, 2013, 2014, 2015, 2016, 2017, 2019, 2021, 2022'),
#   ('Feni Industries', '2008, 2010, 2011'),
#   ('Strumica 2005', '2007'),
#   ('Nikol Fert Gostivar', '2000'),
#   ('Kumanovo', '/'),
#   ('Vardar', '/'),
#   ('Kočani Delikates', '/'),
#   ('Pelister', '/'),
#   ('Karpoš Sokoli', '/'),
#   ('Kožuv', '/'),
#   ('Vardar Osiguruvanje', '/'),
#   ('Žito Vardar', '/')],
#  'Euroleague': [('Real Madrid',
#    '1963–64, 1964–65, 1966–67, 1967–68, 1973–74, 1977–78, 1979–80, 1994–95, 2014–15, 2017–18'),
#   ('CSKA Moscow',
#    '1960–61, 1962–63, 1968–69, 1970–71, 2005–06, 2007–08, 2015–16, 2018–19'),
#   ('Maccabi Tel Aviv', '1976–77, 1980–81, 2000–01, 2003–04, 2004–05, 2013–14'),
#   ('Panathinaikos', '1995–96, 1999–00, 2001–02, 2006–07, 2008–09, 2010–11'),
#   ('Varese', '1969–70, 1971–72, 1972–73, 1974–75, 1975–76'),
#   ('Olympiacos', '1996–97, 2011–12, 2012–13'),
#   ('Olimpia Milano', '1965–66, 1986–87, 1987–88'),
#   ('Rīgas ASK', '1958, 1958–59, 1959–60'),
#   ('Split', '1988–89, 1989–90, 1990–91'),
#   ('Barcelona', '2002–03, 2009–10'),
#   ('Virtus Bologna', '1997–98, 2000–01'),
#   ('Anadolu Efes', '2020–21, 2021–22'),
#   ('Cantù', '1981–82, 1982–83'),
#   ('Cibona', '1984–85, 1985–86'),
#   ('Fenerbahçe', '2016–17'),
#   ('Dinamo Tbilisi', '1961–62'),
#   ('Joventut Badalona', '1993–94'),
#   ('Žalgiris', '1998–99'),
#   ('Bosna', '1978–79'),
#   ('Virtus Roma', '1983–84'),
#   ('Partizan', '1991–92'),
#   ('Limoges CSP', '1992–93'),
#   ('Academic', '–'),
#   ('Brno', '–'),
#   ('Treviso', '–'),
#   ('Baskonia', '–'),
#   ('USK Praha', '–'),
#   ('AEK', '–'),
#   ('Fortitudo Bologna', '–')],
#  'Turkish-BSL': [('Anadolu Efes',
#    '1979, 1983, 1984, 1992, 1993, 1994, 1996, 1997, 2002, 2003, 2004, 2005, 2009, 2019, 2021'),
#   ('Fenerbahçe', '1991, 2007, 2008, 2010, 2011, 2014, 2016, 2017, 2018, 2022'),
#   ('Eczacıbaşı', '1976, 1977, 1978, 1980, 1981, 1982, 1988, 1989'),
#   ('Galatasaray', '1969, 1985, 1986, 1990, 2013'),
#   ('İTÜ', '1968, 1970, 1971, 1972, 1973'),
#   ('Ülker', '1995, 1998, 2001, 2006'),
#   ('Beşiktaş', '1975, 2012'),
#   ('Tofaş', '1999, 2000'),
#   ('Karşıyaka', '1987, 2015'),
#   ('Altınordu', '1967'),
#   ('Muhafızgücü', '1974'),
#   ('Çukurova Sanayi', nan),
#   ('Paşabahçe', nan),
#   ('Şekerspor', nan),
#   ('Türk Telekom', nan),
#   ('Bandırma Basketbol', nan)],
#  'New-Zealand-NB': [('Wellington Saints',
#    '1984, 1985, 1987, 1988, 2003, 2010, 2011, 2014, 2016, 2017, 2019, 2021'),
#   ('Auckland Stars', '1982, 1983, 1995, 1996, 1997, 1999, 2000, 2004, 2005'),
#   ('Canterbury Rams', '1986, 1989, 1990, 1992'),
#   ('Waikato Pistons', '2001, 2002, 2008, 2009'),
#   ('Nelson Giants', '1994, 1998, 2007'),
#   ('Southland Sharks', '2013, 2015, 2018'),
#   ('Hutt Valley Lakers', '1991, 1993'),
#   ('Otago Nuggets', '2020, 2022'),
#   ("Hawke's Bay Hawks", '2006'),
#   ('Auckland Pirates', '2012'),
#   ('Harbour Heat', nan),
#   ('Manawatu Jets', nan),
#   ('Waitemata Dolphins', nan),
#   ('Super City Rangers', nan),
#   ('Auckland Tuatara', nan)],
#  'Spanish-Cup': [('Real Madrid',
#    '1951, 1952, 1954, 1956, 1957, 1960, 1961, 1962, 1965, 1966, 1967, 1970, 1971, 1972, 1973, 1974, 1975, 1977, 1985, 1986, 1989, 1993, 2012, 2014, 2015, 2016, 2017, 2020'),
#   ('Barcelona',
#    '1943, 1945, 1946, 1947, 1949, 1950, 1959, 1978, 1979, 1980, 1981, 1982, 1983, 1987, 1988, 1991, 1994, 2001, 2003, 2007, 2010, 2011, 2013, 2018, 2019, 2021, 2022'),
#   ('Joventut', '1948, 1953, 1955, 1958, 1969, 1976, 1997, 2008'),
#   ('Baskonia', '1995, 1999, 2002, 2004, 2006, 2009'),
#   ('Estudiantes', '1963, 1992, 2000'),
#   ('Laietà', '1942, 1944'),
#   ('Zaragoza', '1984, 1990'),
#   ('Málaga', '2005, 2023'),
#   ('Rayo Club Madrid', '1933, 1936'),
#   ('Picadero', '1964, 1968'),
#   ('Valencia Basket', '1998'),
#   ('Societé Patrie', '1935'),
#   ("L'Hospitalet", '1940'),
#   ('Manresa', '1996'),
#   ('Espanyol', '1941'),
#   ('Aismalíbar', nan),
#   ('Inmobanco', nan),
#   ('Montgat', nan),
#   ('Canarias de Madrid', nan),
#   ('Hesperia', nan),
#   ('Náutico Tenerife', nan),
#   ('Kas Vitoria', nan),
#   ('Cáceres', nan),
#   ('Sevilla', nan),
#   ('Gran Canaria', nan),
#   ('Canarias', nan)],
#  'French-LNB-Espoirs': [('ASVEL',
#    '1949–50, 1950–51, 1951–52, 1954–55, 1955–56, 1956–57, 1963–64, 1965–66, 1967–68, 1968–69, 1970–71, 1971–72, 1974–75, 1976–77, 1980–81, 2001–02, 2008–09, 2015–16, 2018–19, 2020–21, 2021–22'),
#   ('Limoges CSP',
#    '1982–83, 1983–84, 1984–85, 1987–88, 1988–89, 1989–90, 1992–93, 1993–94, 1999–00, 2013–14, 2014–15'),
#   ('Pau-Lacq-Orthez',
#    '1985–86, 1986–87, 1991–92, 1995–96, 1997–98, 1998–99, 2000–01, 2002–03, 2003–04'),
#   ('FAM', '1923–24, 1924–25, 1925–26, 1927–28, 1928–29, 1929–30, 1930–31'),
#   ('Le Mans Sarthe', '1977–78, 1978–79, 1981–82, 2005–06, 2017–18'),
#   ('Racing Paris', '1950–51, 1952–53, 1953–54, 1996–97'),
#   ('Alsace de Bagnolet', '1960–61, 1961–62, 1966–67'),
#   ('Olympique Antibes', '1969–70, 1990–91, 1994–95'),
#   ('Stade Français', '1920–21, 1926–27'),
#   ('CAUFA Reims', '1931–32, 1932–33'),
#   ('CAM', '1934–35, 1936–37'),
#   ('SCPO', '1935–36, 1937–38'),
#   ('Métro', '1938–39, 1941–42'),
#   ('Grenoble', '1942–43, 1943–44'),
#   ('Étoile Charleville-Mézières', '1957–58, 1959–60'),
#   ('PUC', '1946–47, 1962–63'),
#   ('Berck', '1972–73, 1973–74'),
#   ('ASPO Tours', '1975–76, 1979–80'),
#   ('Chorale Roanne', '1958–59, 2006–07'),
#   ('SLUC Nancy', '2007–08, 2010–11'),
#   ('Élan Chalon', '2011–12, 2016–17'),
#   ('ICAM Lille', '1921–22'),
#   ('École Normale Arras', '1922–23'),
#   ('Olympique Lillois', '1933–34'),
#   ('Championnet Sports', '1944–45'),
#   ('ESSMG Lyon', '1945–46'),
#   ('Marseille', '1947–48'),
#   ('Denain Voltaire', '1964–65'),
#   ('SIG', '2004–05'),
#   ('Cholet', '2009–10'),
#   ('Nanterre 92', '2012–13')],
#  'German-BBL': [('Bayer 04 Leverkusen',
#    '1969–70, 1970–71, 1971–72, 1975–76, 1978–79, 1984–85, 1985–86, 1989–90, 1990–91, 1991–92, 1992–93, 1993–94, 1994–95, 1995–96'),
#   ('Alba Berlin',
#    '1996–97, 1997–98, 1998–99, 1999–00, 2000–01, 2001–02, 2002–03, 2007–08, 2019–20, 2020–21, 2021–22'),
#   ('USC Heidelberg',
#    '1956–57, 1957–58, 1958–59, 1959–60, 1960–61, 1961–62, 1965–66, 1972–73, 1976–77'),
#   ('Brose Bamberg',
#    '2004–05, 2006–07, 2009–10, 2010–11, 2011–12, 2012–13, 2014–15, 2015–16, 2016–17'),
#   ('Bayern Munich', '1953–54, 1954–55, 2013–14, 2017–18, 2018–19'),
#   ('Gießen 46ers', '1964–65, 1966–67, 1967–68, 1974–75, 1977–78'),
#   ('Turnerbund Heidelberg', '1947–48, 1950–51, 1951–52, 1952–53'),
#   ('Saturn Köln', '1980–81, 1981–82, 1986–87, 1987–88'),
#   ('ASC 1846 Göttingen', '1979–80, 1982–83, 1983–84'),
#   ('Alemannia Aachen', '1962–63, 1963–64'),
#   ('MTSV Schwabing', '1946–47, 1948–49'),
#   ('LSV Spandau', '1938–39'),
#   ('Stuttgart-Degerloch', '1949–50'),
#   ('ATV Düsseldorf', '1955–56'),
#   ('Osnabrück', '1968–69'),
#   ('SSV Hagen', '1973–74'),
#   ('Steiner Bayreuth', '1988–89'),
#   ('Skyliners Frankfurt', '2003–04'),
#   ('RheinStars Köln', '2005–06'),
#   ('EWE Baskets Oldenburg', '2008–09')],
#  'Basketball-Champions-League-': [('Canarias', '2017, 2022'),
#   ('San Pablo Burgos', '2020, 2021'),
#   ('AEK', '2018'),
#   ('Virtus Bologna', '2019'),
#   ('Baskets Bonn', '2023'),
#   ('Bandırma', '–'),
#   ('Monaco', '–'),
#   ('Karşıyaka', '–'),
#   ('Manresa', '–'),
#   ('Hapoel Jerusalem', '–')],
#  'French-Jeep-Elite': [('ASVEL',
#    '1949–50, 1950–51, 1951–52, 1954–55, 1955–56, 1956–57, 1963–64, 1965–66, 1967–68, 1968–69, 1970–71, 1971–72, 1974–75, 1976–77, 1980–81, 2001–02, 2008–09, 2015–16, 2018–19, 2020–21, 2021–22'),
#   ('Limoges CSP',
#    '1982–83, 1983–84, 1984–85, 1987–88, 1988–89, 1989–90, 1992–93, 1993–94, 1999–00, 2013–14, 2014–15'),
#   ('Pau-Lacq-Orthez',
#    '1985–86, 1986–87, 1991–92, 1995–96, 1997–98, 1998–99, 2000–01, 2002–03, 2003–04'),
#   ('FAM', '1923–24, 1924–25, 1925–26, 1927–28, 1928–29, 1929–30, 1930–31'),
#   ('Le Mans Sarthe', '1977–78, 1978–79, 1981–82, 2005–06, 2017–18'),
#   ('Racing Paris', '1950–51, 1952–53, 1953–54, 1996–97'),
#   ('Alsace de Bagnolet', '1960–61, 1961–62, 1966–67'),
#   ('Olympique Antibes', '1969–70, 1990–91, 1994–95'),
#   ('Stade Français', '1920–21, 1926–27'),
#   ('CAUFA Reims', '1931–32, 1932–33'),
#   ('CAM', '1934–35, 1936–37'),
#   ('SCPO', '1935–36, 1937–38'),
#   ('Métro', '1938–39, 1941–42'),
#   ('Grenoble', '1942–43, 1943–44'),
#   ('Étoile Charleville-Mézières', '1957–58, 1959–60'),
#   ('PUC', '1946–47, 1962–63'),
#   ('Berck', '1972–73, 1973–74'),
#   ('ASPO Tours', '1975–76, 1979–80'),
#   ('Chorale Roanne', '1958–59, 2006–07'),
#   ('SLUC Nancy', '2007–08, 2010–11'),
#   ('Élan Chalon', '2011–12, 2016–17'),
#   ('ICAM Lille', '1921–22'),
#   ('École Normale Arras', '1922–23'),
#   ('Olympique Lillois', '1933–34'),
#   ('Championnet Sports', '1944–45'),
#   ('ESSMG Lyon', '1945–46'),
#   ('Marseille', '1947–48'),
#   ('Denain Voltaire', '1964–65'),
#   ('SIG', '2004–05'),
#   ('Cholet', '2009–10'),
#   ('Nanterre 92', '2012–13')],
#  'Swiss-LNA': [('Fribourg Olympic',
#    '1965–66, 1970–71, 1972–73, 1973–74, 1977–78, 1978–79, 1980–81, 1981–82, 1984–85, 1991–92, 1996–97, 1997–98, 1998–99, 2006–07, 2007–08, 2015–16, 2017–18, 2018–19, 2020–21, 2021–22'),
#   ('Urania Genève',
#    '1933–34, 1937–38, 1940–41, 1941–42, 1942–43, 1943–44, 1945–46, 1946–47, 1947–48, 1948–49, 1957–58, 1958–59, 1963–64, 1964–65, 1966–67'),
#   ('Lugano Tigers',
#    '1999–2000, 2000–01, 2001–02, 2005–06, 2009–10, 2010–11, 2011–12, 2013–14'),
#   ('Stade Français Genève',
#    '1949–50, 1959–60, 1961–62, 1967–68, 1968–69, 1969–70, 1971–72'),
#   ('Jonction', '1951–52, 1952–53, 1953–54, 1954–55, 1955–56, 1956–57'),
#   ('Pully', '1985–86, 1986–87, 1988–89, 1989–90'),
#   ('Monthey', '1995–96, 2004–05, 2016–17'),
#   ('Bellinzona', '1992–93, 1993–94, 1994–95'),
#   ('Federale', '1974–75, 1975–76, 1976–77'),
#   ('Servette', '1932–33, 1934–35, 1935–36'),
#   ('Lions de Genève', '2012–13, 2014–15'),
#   ('Boncourt', '2002–03, 2003–04'),
#   ('Sanas Merry Boys / BBC Lausanne', '1950–51, 1962–63'),
#   ('Vevey', '1983–84, 1990–91'),
#   ('Vacallo', '2008–09'),
#   ('Champel Genève', '1987–88'),
#   ('Nyon', '1982–83'),
#   ('Viganello', '1979–80'),
#   ('CAG Genève', '1945–46'),
#   ('Genève', '1936–37'),
#   ('Uni Bern', '1931–32')],
#  'Greek-HEBA-A2': [('Panathinaikos',
#    '1945–46, 1946–47, 1949–50, 1950–51, 1953–54, 1960–61, 1961–62, 1966–67, 1968–69, 1970–71, 1971–72, 1972–73, 1973–74, 1974–75, 1976–77, 1979–80, 1980–81, 1981–82, 1983–84, 1997–98, 1998–99, 1999–2000, 2000–01, 2002–03, 2003–04, 2004–05, 2005–06, 2006–07, 2007–08, 2008–09, 2009–10, 2010–11, 2012–13, 2013–14, 2016–17, 2017–18, 2018–19, 2019-20, 2020–21'),
#   ('Olympiacos',
#    '1948–49, 1959–60, 1975–76, 1977–78, 1992–93, 1993–94, 1994–95, 1995–96, 1996–97, 2011–12, 2014–15, 2015–16, 2021–22'),
#   ('Aris',
#    '1929–30, 1978–79, 1982–83, 1984–85, 1985–86, 1986–87, 1987–88, 1988–89, 1989–90, 1990–91'),
#   ('AEK',
#    '1957–58, 1962–63, 1963–64, 1964–65, 1965–66, 1967–68, 1969–70, 2001–02'),
#   ('Panellinios', '1928–29, 1938–39, 1939–40, 1952–53, 1954–55, 1956–57'),
#   ('Iraklis', '1927–28, 1934–35'),
#   ('PAOK', '1958–59, 1991–92'),
#   ('Near East', '1935–36'),
#   ('Athens University', '1936–37')],
#  'Turkish-TBL': [('Anadolu Efes',
#    '1979, 1983, 1984, 1992, 1993, 1994, 1996, 1997, 2002, 2003, 2004, 2005, 2009, 2019, 2021'),
#   ('Fenerbahçe', '1991, 2007, 2008, 2010, 2011, 2014, 2016, 2017, 2018, 2022'),
#   ('Eczacıbaşı', '1976, 1977, 1978, 1980, 1981, 1982, 1988, 1989'),
#   ('Galatasaray', '1969, 1985, 1986, 1990, 2013'),
#   ('İTÜ', '1968, 1970, 1971, 1972, 1973'),
#   ('Ülker', '1995, 1998, 2001, 2006'),
#   ('Beşiktaş', '1975, 2012'),
#   ('Tofaş', '1999, 2000'),
#   ('Karşıyaka', '1987, 2015'),
#   ('Altınordu', '1967'),
#   ('Muhafızgücü', '1974'),
#   ('Çukurova Sanayi', nan),
#   ('Paşabahçe', nan),
#   ('Şekerspor', nan),
#   ('Türk Telekom', nan),
#   ('Bandırma Basketbol', nan)],
#  'Basketball-Africa-League---Qualification': [('US Monastir', '2022'),
#   ('Zamalek', '2021'),
#   ('Petro de Luanda', '—')],
#  'Greek-HEBA-A1': [('Panathinaikos',
#    '1945–46, 1946–47, 1949–50, 1950–51, 1953–54, 1960–61, 1961–62, 1966–67, 1968–69, 1970–71, 1971–72, 1972–73, 1973–74, 1974–75, 1976–77, 1979–80, 1980–81, 1981–82, 1983–84, 1997–98, 1998–99, 1999–2000, 2000–01, 2002–03, 2003–04, 2004–05, 2005–06, 2006–07, 2007–08, 2008–09, 2009–10, 2010–11, 2012–13, 2013–14, 2016–17, 2017–18, 2018–19, 2019-20, 2020–21'),
#   ('Olympiacos',
#    '1948–49, 1959–60, 1975–76, 1977–78, 1992–93, 1993–94, 1994–95, 1995–96, 1996–97, 2011–12, 2014–15, 2015–16, 2021–22'),
#   ('Aris',
#    '1929–30, 1978–79, 1982–83, 1984–85, 1985–86, 1986–87, 1987–88, 1988–89, 1989–90, 1990–91'),
#   ('AEK',
#    '1957–58, 1962–63, 1963–64, 1964–65, 1965–66, 1967–68, 1969–70, 2001–02'),
#   ('Panellinios', '1928–29, 1938–39, 1939–40, 1952–53, 1954–55, 1956–57'),
#   ('Iraklis', '1927–28, 1934–35'),
#   ('PAOK', '1958–59, 1991–92'),
#   ('Near East', '1935–36'),
#   ('Athens University', '1936–37')],
#  'Puerto-Rican-BSN': [('Vaqueros de Bayamón',
#    '1933, 1935, 1967, 1969, 1971,1972, 1973, 1974, 1975, 1981,1988, 1995, 1996, 2009, 2020, 2022'),
#   ('Atléticos de San Germán',
#    '1932, 1938, 1939, 1941, 1942,1943, 1947, 1948, 1949,1950, 1985, 1991, 1994, 1997'),
#   ('Leones de Ponce',
#    '1952, 1954, 1960, 1961, 1964,1965, 1966, 1990, 1992, 1993,2002, 2004, 2014, 2015'),
#   ('Cangrejeros de Santurce', '1962, 1968, 1998, 1999, 2000,2001, 2003, 2007'),
#   ('Capitanes de Arecibo', '1959, 2005, 2008, 2010, 2011, 2016, 2018, 2021'),
#   ('Cardenales de Río Piedras', '1946, 1955, 1956, 1957,1963,1976'),
#   ('Piratas de Quebradillas', '1970, 1977, 1978, 1979, 2013, 2017'),
#   ('Capitalinos de San Juan', '1930, 1931, 1940, 1945, 1958'),
#   ('Mets de Guaynabo', '1980, 1982, 1989'),
#   ('Vega Baja', '1934, 1937'),
#   ('Indios de Canóvanas', '1983, 1984'),
#   ('Gallitos de la UPR', '1944, 1951'),
#   ('Polluelos de Aibonito', '1986'),
#   ('Club Náutico San Juan', '1936'),
#   ('Criollos de Caguas', '2006'),
#   ('Indios de Mayagüez', '2012'),
#   ('Titanes de Morovis', '1987'),
#   ('Gigantes de Carolina', '—'),
#   ('Brujos de Guayama', '—'),
#   ('Gallitos de Isabela', '—'),
#   ('Maratonistas de Coamo', '—'),
#   ('Santeros de Aguada', '2019')],
#  'FIBA-Europe-Cup---Qualification': [('Skyliners Frankfurt', '2016'),
#   ('Nanterre 92', '2017'),
#   ('Reyer Venezia', '2018'),
#   ('Dinamo Sassari', '2019'),
#   ('Ironi Nes Ziona', '2021'),
#   ('Bahçeşehir Koleji', '2022'),
#   ('Anwil Włocławek', '2023'),
#   ('Varese', '–'),
#   ('Élan Chalon', '–'),
#   ('Felice Scandone', '–'),
#   ('Würzburg', '–'),
#   ('Stal Ostrów Wielkopolski', '–'),
#   ('Reggiana', '–'),
#   ('Cholet Basket', '–')],
#  'Mexican-CIBACOPA': [('Team', '2012, 2013, 2019'),
#   ('Team', '2002, 2003, 2007')],
#  'French-Leaders-Cup-LNB-A': [('Pau-Lacq-Orthez', '1991, 1992, 1993, 2003'),
#   ('Le Mans Sarthe', '2006, 2009, 2014'),
#   ('Monaco', '2016, 2017, 2018'),
#   ('Limoges CSP', '1988, 1990'),
#   ('BCM Gravelines', '2011, 2013'),
#   ('ASVEL', '2010, 2023'),
#   ('SIG', '2015, 2019'),
#   ('JDA Dijon', '2004, 2020'),
#   ('Cholet', '2008'),
#   ('Élan Chalon', '2012'),
#   ('Mulhouse', '1989'),
#   ('SLUC Nancy', '2005'),
#   ('Chorale Roanne', '2007'),
#   ('JL Bourg-en-Bresse', nan),
#   ('Orléans', nan),
#   ('Le Havre', nan),
#   ('JA Vichy', nan),
#   ('Nanterre 92', nan)],
#  'Hungarian-NBIA': [('Bp. Honvéd',
#    '1952, 1953, 1954, 1955, 1957, 1957–58, 1958–59, 1959–60, 1960–61, 1961–62, 1962–63, 1964, 1965, 1966, 1967,1968, 1969, 1971, 1974, 1976, 1977, 1978, 1979, 1980–81, 1981–82, 1982–83, 1983–84, 1984–85, 1985–86, 1992–93,1993–94, 1994–95, 1996–97'),
#   ('BSZKRT Előre',
#    '1934, 1936–37, 1937–38, 1938–39, 1939–40, 1940–41, 1943–44, 1945, 1948–49'),
#   ('Szolnoki Olajbányász',
#    '1990–91, 2006–07, 2010–11, 2011–12, 2013–14, 2014–15, 2015–16, 2017–18'),
#   ('MAFC', '1935–36, 1944, 1949–50, 1951, 1956, 1970, 1975'),
#   ('Alba Fehérvár', '1997–98, 1998–99, 1999–2000, 2012–13, 2016–17'),
#   ('Atomerőmű', '2001–02, 2004–05, 2005–06, 2008–09'),
#   ('ZTE', '1987–88, 1989–90, 1991–92, 2009–10'),
#   ('Falco', '2007–08, 2018–19, 2020–21, 2021–22'),
#   ('Csepel', '1972, 1973, 1988–89'),
#   ('Körmend', '1986–87, 1995–96, 2002–03'),
#   ('Kaposvár', '2000–01, 2003–04'),
#   ('BEAC', '1941–42, 1942–43'),
#   ('MÁVAG', '1947–48, 1950'),
#   ('Közgazdasági Egyetem', '1933'),
#   ('TFSE', '1934–35'),
#   ('Budapesti Kinizsi TE', '1946'),
#   ('Budapesti Postás', '1946–47')],
#  'FIBA-Europe-Cup': [('Skyliners Frankfurt', '2016'),
#   ('Nanterre 92', '2017'),
#   ('Reyer Venezia', '2018'),
#   ('Dinamo Sassari', '2019'),
#   ('Ironi Nes Ziona', '2021'),
#   ('Bahçeşehir Koleji', '2022'),
#   ('Anwil Włocławek', '2023'),
#   ('Varese', '–'),
#   ('Élan Chalon', '–'),
#   ('Felice Scandone', '–'),
#   ('Würzburg', '–'),
#   ('Stal Ostrów Wielkopolski', '–'),
#   ('Reggiana', '–'),
#   ('Cholet Basket', '–')]}
